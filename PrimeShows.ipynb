# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df = pd.read_csv("MoviesOnStreamingPlatforms.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9515 entries, 0 to 9514
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       9515 non-null   int64
#  1   ID               9515 non-null   int64
#  2   Title            9515 non-null   object
#  3   Year             9515 non-null   int64
#  4   Age              5338 non-null   object
#  5   Rotten Tomatoes  9508 non-null   object
#  6   Netflix          9515 non-null   int64
#  7   Hulu             9515 non-null   int64
#  8   Prime Video      9515 non-null   int64
#  9   Disney+          9515 non-null   int64
#  10  Type             9515 non-null   int64
# dtypes: int64(8), object(3)
# memory usage: 817.8+ KB

# %%
df.head(5).transpose()
# Out:
#                             0       1  \
# Unnamed: 0                  0       1
# ID                          1       2
# Title            The Irishman  Dangal
# Year                     2019    2016
# Age                       18+      7+
# Rotten Tomatoes        98/100  97/100
# Netflix                     1       1
# Hulu                        0       0
# Prime Video                 0       0
# Disney+                     0       0
# Type                        0       0
#
#                                                         2  \
# Unnamed: 0                                              2
# ID                                                      3
# Title            David Attenborough: A Life on Our Planet
# Year                                                 2020
# Age                                                    7+
# Rotten Tomatoes                                    95/100
# Netflix                                                 1
# ...

# %%
df.drop('Unnamed: 0', inplace=True, axis=1)

# %%
df.head(5).transpose()
# Out:
#                             0       1  \
# ID                          1       2
# Title            The Irishman  Dangal
# Year                     2019    2016
# Age                       18+      7+
# Rotten Tomatoes        98/100  97/100
# Netflix                     1       1
# Hulu                        0       0
# Prime Video                 0       0
# Disney+                     0       0
# Type                        0       0
#
#                                                         2  \
# ID                                                      3
# Title            David Attenborough: A Life on Our Planet
# Year                                                 2020
# Age                                                    7+
# Rotten Tomatoes                                    95/100
# Netflix                                                 1
# Hulu                                                    0
# Prime Video                                             0
# ...

# %%
df["Rotten Tomatoes"] = df["Rotten Tomatoes"].str.replace("/100","")

# %%
df["Rotten Tomatoes"] = df["Rotten Tomatoes"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9515 entries, 0 to 9514
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               9515 non-null   int64
#  1   Title            9515 non-null   object
#  2   Year             9515 non-null   int64
#  3   Age              5338 non-null   object
#  4   Rotten Tomatoes  9508 non-null   float64
#  5   Netflix          9515 non-null   int64
#  6   Hulu             9515 non-null   int64
#  7   Prime Video      9515 non-null   int64
#  8   Disney+          9515 non-null   int64
#  9   Type             9515 non-null   int64
# dtypes: float64(1), int64(7), object(2)
# memory usage: 743.5+ KB

# %%
sns.pairplot(df)

# %%
df["Netflix"].value_counts()
# Out:
# 0    5820
# 1    3695
# Name: Netflix, dtype: int64

# %%
df["Disney+"].value_counts()
# Out:
# 0    8593
# 1     922
# Name: Disney+, dtype: int64

# %%
df["Hulu"].value_counts()
# Out:
# 0    8468
# 1    1047
# Name: Hulu, dtype: int64

# %%
df["Prime Video"].value_counts()
# Out:
# 0    5402
# 1    4113
# Name: Prime Video, dtype: int64

# %%
df["Age"].value_counts()
# Out:
# 18+    2276
# 7+     1090
# 13+     998
# all     698
# 16+     276
# Name: Age, dtype: int64

# %%
df["Year"].value_counts()
# Out:
# 2019    1014
# 2018     945
# 2020     862
# 2017     831
# 2016     644
#         ...
# 1922       1
# 1927       1
# 1919       1
# 1923       1
# 1916       1
# Name: Year, Length: 103, dtype: int64

# %%
sns.distplot(df['Year'],color="y")
# Out:
# D:\Users\mthoufeeq\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Year', ylabel='Density'>

# %%
df.transpose()
# Out:
#                          0       1     \
# ID                          1       2
# Title            The Irishman  Dangal
# Year                     2019    2016
# Age                       18+      7+
# Rotten Tomatoes          98.0    97.0
# Netflix                     1       1
# Hulu                        0       0
# Prime Video                 0       0
# Disney+                     0       0
# Type                        0       0
#
#                                                      2     \
# ID                                                      3
# Title            David Attenborough: A Life on Our Planet
# Year                                                 2020
# Age                                                    7+
# Rotten Tomatoes                                      95.0
# Netflix                                                 1
# Hulu                                                    0
# Prime Video                                             0
# ...

# %%
sns.boxplot(x='Netflix',y='Rotten Tomatoes',data=df,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Netflix', ylabel='Rotten Tomatoes'>

# %%
sns.countplot(x='Age',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
assos = df[df["Netflix"] == 1]

# %%
sns.histplot(data=assos,x="Rotten Tomatoes",y="Netflix")
# Out:
# <AxesSubplot:xlabel='Rotten Tomatoes', ylabel='Netflix'>

# %%
assos = df[df["Disney+"] == 1]

# %%
sns.histplot(data=assos,x="Rotten Tomatoes",y="Disney+")
# Out:
# <AxesSubplot:xlabel='Rotten Tomatoes', ylabel='Disney+'>

# %%
assos = df[df["Prime Video"] == 1]

# %%
sns.histplot(data=assos,x="Rotten Tomatoes",y="Prime Video")
# Out:
# <AxesSubplot:xlabel='Rotten Tomatoes', ylabel='Prime Video'>

# %%
assos = df[df["Hulu"] == 1]

# %%
sns.histplot(data=assos,x="Rotten Tomatoes",y="Hulu")
# Out:
# <AxesSubplot:xlabel='Rotten Tomatoes', ylabel='Hulu'>

# %%
akg = df[df["Rotten Tomatoes"] > 75.0]

# %%
sum = akg[akg["Netflix"]==1]

# %%
sns.scatterplot(data=sum,x="Age",y="Rotten Tomatoes")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Rotten Tomatoes'>

# %%
sum = akg[akg["Disney+"]==1]

# %%
sns.scatterplot(data=sum,x="Age",y="Rotten Tomatoes")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Rotten Tomatoes'>

# %%
sum = akg[akg["Prime Video"]==1]

# %%
sns.scatterplot(data=sum,x="Age",y="Rotten Tomatoes")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Rotten Tomatoes'>

# %%
sum = akg[akg["Hulu"]==1]

# %%
sns.scatterplot(data=sum,x="Age",y="Rotten Tomatoes")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Rotten Tomatoes'>
